# %% [markdown]
# # KPI-1: Profit

# %% [markdown]
# # Testing

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
data_path = 'D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/'
ProfitMax = pd.read_csv(data_path + 'ProfitMax.csv')
PooledRide = pd.read_csv(data_path + 'PooledRide.csv')
PrivateRide = pd.read_csv(data_path + 'PrivateRide.csv')

# Set up the figure
plt.figure(figsize=(8.5, 6.5))  # Adjusted figure size

# Plot KDE and rugplot for each ride type
ride_types = [ProfitMax, PooledRide, PrivateRide]
colors = ['darkblue', 'darkgreen', 'darkred']
labels = ['Profit Maximization', 'Pooled Rides', 'Solo Rides']

for i, ride_type in enumerate(ride_types):
    sns.kdeplot(data=ride_type['REVENUE'], shade=True, color=colors[i], label=labels[i])
    sns.rugplot(data=ride_type['REVENUE'], color=colors[i], height=0.05)

# Set title and labels with increased font size
plt.title('Revenue Distribution of Pricing Strategies', fontsize=16)  # Increased title font size
plt.xlabel('Drivers (veh)', fontsize=14)  # Increased x-axis label font size
plt.ylabel('Revenue', fontsize=14)  # Changed y-axis label to "Revenue"

# Redefine x-axis ticks to range from 1 to 50
#plt.xticks(range(1, 51), fontsize=12)

# Increase font size of y-axis tick labels
plt.yticks(fontsize=12)

# Add a legend with increased label font size
plt.legend(fontsize=12)  # Increased legend label font size

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Save the figure as a high-quality PDF
plt.savefig(data_path + 'revenue_distribution.pdf', bbox_inches='tight', format='pdf')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data for Strategy 1: Profit Maximization
veh_1 = list(range(1, 51))
revenue_1 = [
    3.7404, 1.6428, 4.5144, 3.1368, 5.2908, 5.082, 2.7384, 5.268, 5.7132, 1.5312,
    4.572, 0.4008, 2.1216, 4.1508, 1.818, 0.87, 2.9784, 0.9264, 1.7772, 5.472,
    2.3544, 3.618, 2.382, 2.9256, 3.582, 5.8908, 1.1352, 2.58, 1.932, 2.0988,
    2.4852, 0.1584, 2.7636, 2.13, 0.054, 2.8056, 2.832, 2.2176, 2.5248, 5.3436,
    2.9556, 4.8924, 2.7204, 2.6832, 5.1288, 2.3844, 4.2024, 1.8876, 2.6556, 2.97
]

# Data for Strategy 2
veh_2 = list(range(1, 51))
revenue_2 = [
    4.1004, 1.194, 5.6688, 5.9796, 4.4604, 6.084, 1.5864, 4.8144, 6.7524, 7.4028,
    4.7364, 2.4168, 4.8588, 2.1912, 3.198, 1.2288, 3.8184, 2.2824, 0.5424, 0.3384,
    4.416, 3.3468, 4.6776, 2.8344, 1.8864, 1.0236, 0.1236, 0.7116, 4.2144, 2.3184,
    2.1672, 0.8436, 1.5372, 1.1712, 0.2196, 2.3196, 0.8976, 7.7436, 1.9572, 3.8148,
    1.794, 3.2064, 5.3148, 4.2948, 6.24, 1.4004, 1.5888, 5.1408, 0.6216, 3.8964
]

# Set up the figure
plt.figure(figsize=(8.5, 6.5))  # Adjusted figure size

# Plot histogram for Strategy 1 data
sns.histplot(data=revenue_1, color='darkblue', label='Strategy 1: Profit Maximization', kde=True)

# Plot histogram for Strategy 2 data
sns.histplot(data=revenue_2, color='darkgreen', label='Strategy 2', kde=True)

# Set title and labels with increased font size
plt.title('Revenue Distribution of Strategies', fontsize=16)  # Increased title font size
plt.xlabel('REVENUE', fontsize=14)  # Increased x-axis label font size
plt.ylabel('Frequency', fontsize=14)  # Increased y-axis label font size

# Increase font size of tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add a legend with increased label font size
plt.legend(fontsize=12)  # Increased legend label font size

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 28>()
#      25 plt.figure(figsize=(8.5, 6.5))  # Adjusted figure size
#      27 # Plot histogram for Strategy 1 data
# ---> 28 sns.distplot(data=revenue_1, color='darkblue', label='Strategy 1: Profit Maximization', kde=True)
#      30 # Plot histogram for Strategy 2 data
#      31 sns.histplot(data=revenue_2, color='darkgreen', label='Strategy 2', kde=True)
#
# TypeError: distplot() got an unexpected keyword argument 'data'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data for Strategy 1: Profit Maximization
veh_1 = list(range(1, 51))
revenue_1 = [
    3.7404, 1.6428, 4.5144, 3.1368, 5.2908, 5.082, 2.7384, 5.268, 5.7132, 1.5312,
    4.572, 0.4008, 2.1216, 4.1508, 1.818, 0.87, 2.9784, 0.9264, 1.7772, 5.472,
    2.3544, 3.618, 2.382, 2.9256, 3.582, 5.8908, 1.1352, 2.58, 1.932, 2.0988,
    2.4852, 0.1584, 2.7636, 2.13, 0.054, 2.8056, 2.832, 2.2176, 2.5248, 5.3436,
    2.9556, 4.8924, 2.7204, 2.6832, 5.1288, 2.3844, 4.2024, 1.8876, 2.6556, 2.97
]

# Data for Strategy 2
veh_2 = list(range(1, 51))
revenue_2 = [
    4.1004, 1.194, 5.6688, 5.9796, 4.4604, 6.084, 1.5864, 4.8144, 6.7524, 7.4028,
    4.7364, 2.4168, 4.8588, 2.1912, 3.198, 1.2288, 3.8184, 2.2824, 0.5424, 0.3384,
    4.416, 3.3468, 4.6776, 2.8344, 1.8864, 1.0236, 0.1236, 0.7116, 4.2144, 2.3184,
    2.1672, 0.8436, 1.5372, 1.1712, 0.2196, 2.3196, 0.8976, 7.7436, 1.9572, 3.8148,
    1.794, 3.2064, 5.3148, 4.2948, 6.24, 1.4004, 1.5888, 5.1408, 0.6216, 3.8964
]

# Set up the figure
plt.figure(figsize=(8.5, 6.5))  # Adjusted figure size

# Plot distribution plot (Kernel Density Estimate) for Strategy 1 data
sns.distplot(revenue_1, color='darkblue', label='Strategy 1: Profit Maximization')

# Plot distribution plot (Kernel Density Estimate) for Strategy 2 data
sns.distplot(revenue_2, color='darkgreen', label='Strategy 2')

# Set title and labels with increased font size
plt.title('Revenue Distribution of Strategies', fontsize=16)  # Increased title font size
plt.xlabel('REVENUE', fontsize=14)  # Increased x-axis label font size
plt.ylabel('Density', fontsize=14)  # Increased y-axis label font size

# Increase font size of tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add a legend with increased label font size
plt.legend(fontsize=12)  # Increased legend label font size

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()
# Out:
# C:\Users\usman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\usman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
ProfitMax = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/ProfitMax.csv')
PooledRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PooledRide.csv')
PrivateRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PrivateRide.csv')

# Set up the figure
plt.figure(figsize=(7, 5))

# Plot KDE and rugplot for ProfitMax
sns.kdeplot(data=ProfitMax['REVENUE'], shade=True, color='darkblue', label='Profit Maximization')
sns.rugplot(data=ProfitMax['REVENUE'], color='darkblue', height=0.05)

# Plot KDE and rugplot for PooledRide
sns.kdeplot(data=PooledRide['REVENUE'], shade=True, color='darkgreen', label='Pooled Rides')
sns.rugplot(data=PooledRide['REVENUE'], color='darkgreen', height=0.05)

# Plot KDE and rugplot for PrivateRide
sns.kdeplot(data=PrivateRide['REVENUE'], shade=True, color='darkred', label='Solo Rides')
sns.rugplot(data=PrivateRide['REVENUE'], color='darkred', height=0.05)

# Set title and labels
#plt.title('Revenue Distribution of Different Ride Types', fontsize=16)
plt.xlabel('Drivers', fontsize=14)
plt.ylabel('Revenue', fontsize=14)

#plt.xlim(1, 50)

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
data_path = 'D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/'
ProfitMax = pd.read_csv(data_path + 'ProfitMax.csv')
PooledRide = pd.read_csv(data_path + 'PooledRide.csv')
PrivateRide = pd.read_csv(data_path + 'PrivateRide.csv')

# Set up the figure
plt.figure(figsize=(8.5, 6.5))  # Adjusted figure size

# Plot KDE and rugplot for each ride type
ride_types = [ProfitMax, PooledRide, PrivateRide]
colors = ['darkblue', 'darkgreen', 'darkred']
labels = ['Profit Maximization', 'Pooled Rides', 'Solo Rides']

for i, ride_type in enumerate(ride_types):
    sns.kdeplot(data=ride_type['REVENUE'], shade=True, color=colors[i], label=labels[i])
    sns.rugplot(data=ride_type['REVENUE'], color=colors[i], height=0.05)

# Set title and labels with increased font size
plt.title('Revenue Distribution of Pricing Strategies', fontsize=16)  # Increased title font size
plt.xlabel('Drivers', fontsize=14)  # Increased x-axis label font size
plt.ylabel('Density', fontsize=14)  # Increased y-axis label font size

# Increase font size of tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.ylim(0, 0.30)

# Add a legend with increased label font size
plt.legend(fontsize=12)  # Increased legend label font size

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Save the figure as a high-quality PDF
#plt.savefig(data_path + 'revenue_distribution.pdf', bbox_inches='tight', format='pdf')

# Show the plot
plt.show()

# %% [raw]
# #Add the mean line:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
data_path = 'D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/'
ProfitMax = pd.read_csv(data_path + 'ProfitMax.csv')
PooledRide = pd.read_csv(data_path + 'PooledRide.csv')
PrivateRide = pd.read_csv(data_path + 'PrivateRide.csv')

# Set up the figure
plt.figure(figsize=(8.5, 6.5))  # Adjusted figure size

# Plot KDE and rugplot for each ride type
ride_types = [ProfitMax, PooledRide, PrivateRide]
colors = ['darkblue', 'darkgreen', 'darkred']
labels = ['Profit Maximization', 'Pooled Rides', 'Solo Rides']

for i, ride_type in enumerate(ride_types):
    sns.kdeplot(data=ride_type['REVENUE'], shade=True, color=colors[i], label=labels[i], common_norm=False)
    sns.rugplot(data=ride_type['REVENUE'], color=colors[i], height=0.05)
    
    # Calculate mean
    mean = ride_type['REVENUE'].mean()
    # Add mean line
    plt.axvline(x=mean, color=colors[i], linestyle='dashed', linewidth=1.5, label=f'Mean {labels[i]}')

# Set title and labels with increased font size
plt.title('Revenue Distribution of Pricing Strategies', fontsize=16)  # Increased title font size
plt.xlabel('Revenue Distributions', fontsize=14)  # Increased x-axis label font size
plt.ylabel('Density', fontsize=14)  # Increased y-axis label font size

# Set y-axis limit to 0.30
plt.ylim(0, 0.30)

# Increase font size of tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add a legend with increased label font size
plt.legend(fontsize=12)  # Increased legend label font size

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Save the figure as a high-quality PDF
# plt.savefig(data_path + 'revenue_distribution.pdf', bbox_inches='tight', format='pdf')

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
ProfitMax = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/ProfitMax1.csv')
PooledRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PooledRide1.csv')
PrivateRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PrivateRide1.csv')

# Set up the figure
plt.figure(figsize=(8.5, 6.5))  # Adjusted figure size

# Plot KDE and rugplot for ProfitMax
sns.kdeplot(data=ProfitMax['COMMISSION'], shade=True, color='darkblue', label='Profit Maximization')
sns.rugplot(data=ProfitMax['COMMISSION'], color='darkblue', height=0.05)

# Plot KDE and rugplot for PooledRide
sns.kdeplot(data=PooledRide['COMMISSION'], shade=True, color='darkgreen', label='Pooled Rides')
sns.rugplot(data=PooledRide['COMMISSION'], color='darkgreen', height=0.05)

# Plot KDE and rugplot for PrivateRide
sns.kdeplot(data=PrivateRide['COMMISSION'], shade=True, color='darkred', label='Solo Rides')
sns.rugplot(data=PrivateRide['COMMISSION'], color='darkred', height=0.05)

# Set title and labels with increased font size
plt.title('Commission Distribution of Pricing Strategies', fontsize=16)  # Increased title font size
plt.xlabel('Drivers', fontsize=14)  # Increased x-axis label font size
plt.ylabel('Density', fontsize=14)  # Increased y-axis label font size

# Increase font size of tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add a legend with increased label font size
plt.legend(fontsize=12)  # Increased legend label font size

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Save the figure as a high-quality PDF
#plt.savefig('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/COMMISSION_distribution.pdf', bbox_inches='tight', format='pdf')

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
ProfitMax = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/ProfitMax1.csv')
PooledRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PooledRide1.csv')
PrivateRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PrivateRide1.csv')

# Set up the figure
plt.figure(figsize=(8.5, 6.5))  # Adjusted figure size

# Plot KDE and rugplot for ProfitMax
sns.kdeplot(data=ProfitMax['PAX_KM'], shade=True, color='darkblue', label='Profit Maximization')
sns.rugplot(data=ProfitMax['PAX_KM'], color='darkblue', height=0.05)

# Plot KDE and rugplot for PooledRide
sns.kdeplot(data=PooledRide['PAX_KM'], shade=True, color='darkgreen', label='Pooled Rides')
sns.rugplot(data=PooledRide['PAX_KM'], color='darkgreen', height=0.05)

# Plot KDE and rugplot for PrivateRide
sns.kdeplot(data=PrivateRide['PAX_KM'], shade=True, color='darkred', label='Solo Rides')
sns.rugplot(data=PrivateRide['PAX_KM'], color='darkred', height=0.05)

# Set title and labels with increased font size
plt.title('Total distance traveled by passengers', fontsize=16)  # Increased title font size
plt.xlabel('Drivers', fontsize=14)  # Increased x-axis label font size
plt.ylabel('PAX(KM)', fontsize=14)  # Increased y-axis label font size

# Increase font size of tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add a legend with increased label font size
plt.legend(fontsize=12)  # Increased legend label font size

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Save the figure as a high-quality PDF
plt.savefig('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PAXKM_distribution.pdf', bbox_inches='tight', format='pdf')

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
ProfitMax = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/ProfitMax.csv')
PooledRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PooledRide.csv')
PrivateRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PrivateRide.csv')

# Set up the figure
plt.figure(figsize=(8.5, 6.5))  # Adjusted figure size

# Plot KDE and rugplot for ProfitMax
sns.kdeplot(data=ProfitMax['REVENUE'], shade=True, color='darkblue', label='Profit Maximization')
sns.rugplot(data=ProfitMax['REVENUE'], color='darkblue', height=0.05)

# Plot KDE and rugplot for PooledRide
sns.kdeplot(data=PooledRide['REVENUE'], shade=True, color='darkgreen', label='Pooled Rides')
sns.rugplot(data=PooledRide['REVENUE'], color='darkgreen', height=0.05)

# Plot KDE and rugplot for PrivateRide
sns.kdeplot(data=PrivateRide['REVENUE'], shade=True, color='darkred', label='Solo Rides')
sns.rugplot(data=PrivateRide['REVENUE'], color='darkred', height=0.05)

# Set title and labels with increased font size
plt.title('Revenue Distribution of Pricing Strategies', fontsize=16)  # Increased title font size
plt.xlabel('Drivers', fontsize=14)  # Increased x-axis label font size
plt.ylabel('Density', fontsize=14)  # Increased y-axis label font size

# Increase font size of tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add a legend with increased label font size
plt.legend(fontsize=12)  # Increased legend label font size

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Save the figure as a high-quality PDF
plt.savefig('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/revenue_distribution.pdf', bbox_inches='tight', format='pdf')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
drivers = list(range(1, 51))

profit_maximization_distances = [
    40.713, 0, 60.742, 42.25, 35.2, 12.966, 77.694, 41.88, 21.324, 4.579,
    8.13, 28.199, 48.822, 36.655, 31.749, 21.435, 28.806, 55.51, 9.024, 13.062,
    62.524, 10.898, 41.401, 53.953, 11.713, 9.115, 44.159, 7.606, 41.597, 16.047,
    25.965, 16.258, 13.112, 38.234, 27.569, 11.553, 11.251, 8.033, 28.537, 37.707,
    23.281, 21.652, 30.801, 25.138, 3.837, 0, 6.13, 41.648, 29.711, 32.951
]

pooled_rides_distances = [
    14.204, 26.192, 10.022, 11.589, 51.04, 41.642, 5.358, 32.465, 47.094,
    41.714, 36.225, 8.407, 2.362, 12.719, 41.637, 39.015, 42.179, 36.276,
    16.611, 28.17, 19.954, 41.562, 37.803, 21.883, 35.315, 32.065, 23.868,
    22.565, 12.777, 9.571, 16.349, 27.263, 23.596, 9.065, 47.471, 23.717,
    29.468, 19.115, 0, 15.759, 50.015, 32.674, 40.063, 23.363, 40.919,
    24.338, 0, 29.596, 39.058, 4.933
]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(drivers, profit_maximization_distances, marker='o', label='Profit Maximization')
plt.plot(drivers, pooled_rides_distances, marker='o', label='Pooled Rides')
plt.xlabel('Number of Drivers')
plt.ylabel('Total Distance Traveled (km)')
plt.title('Comparison of Travel Distance between Pricing Strategies')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-1-Profit/KPI2_Solo-Rides.csv', index_col=0)
#solo=solo.drop('0',axis='columns')

profitmax = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-1-Profit/KPI1_Profit-Maximization.csv', index_col=0)
#profitmax=profitmax.drop('0',axis='columns')

pooled = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-1-Profit/KPI3_Pooled-Rides.csv', index_col=0)
#pooled=pooled.drop('0',axis='columns')

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)

#vmax_value = 150 # Set your desired vmax value here

s = sns.heatmap(profitmax, annot=True, fmt=".2f", square=True, cbar=True, cmap='viridis', ax=ax1, vmin=0)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title='Profit for Profit Maximization')
s.invert_yaxis()

s = sns.heatmap(pooled, annot=True, fmt=".2f", square=True, cbar=True, cmap='viridis', ax=ax2, vmin=0)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title='Profit for Pooled Rides')
s.invert_yaxis()

s = sns.heatmap(solo, annot=True, fmt=".2f", square=True, cbar=True, cmap='viridis', ax=ax3,  vmin=0)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title='Profit for Solo Rides')
s.invert_yaxis()

# Add caption below X-axis of the third heatmap


fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# # KPI-2: Commision

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-COMMISSION/Solo-Rides.csv', index_col=0)
#solo=solo.drop('0',axis='columns')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-COMMISSION/Profit-Maximization.csv', index_col=0)
#profitmax=profitmax.drop('0',axis='columns')

pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-COMMISSION/Pooled-Rides.csv', index_col=0)
#pooled=pooled.drop('0',axis='columns')
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".2f", square = True, cbar = True, cmap='viridis', ax=ax1, vmin=0, vmax=50)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'COMMISSION earned (Profit Maximization)')
s.invert_yaxis()
s = sns.heatmap(pooled, annot=True, fmt=".2f", square = True, cbar = True, cmap='viridis', ax=ax2, vmin=0, vmax=50)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'COMMISSION earned (Pooled Rides)')
s.invert_yaxis()
s = sns.heatmap(solo, annot=True, fmt=".2f", square = True, cbar = True, cmap='viridis', ax=ax3,  vmin=0, vmax=50)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'COMMISSION earned (Solo Rides)')
s.invert_yaxis()
txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()


fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# # KPI-3: ServiceRate

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.style.use('seaborn-whitegrid')
font = {'size'   : 10}


plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-3-ServiceRate/Solo-Rides.csv',index_col=0)
#solo=solo.drop('0',axis='columns')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-3-ServiceRate/Profit-Maximization.csv',index_col=0)
#profitmax=profitmax.drop('0',axis='columns')

pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-3-ServiceRate/Pooled-Rides.csv', index_col=0)
#pooled=pooled.drop('0',axis='columns')
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)

#sns.heatmap(veh_kpis, cmap="Blues", ax = axes[1], square = True, cbar = True, cbar_ax = cbar_ax)

s = sns.heatmap(profitmax, annot=True,  fmt=".2f", cmap='viridis', ax=ax1, vmin=0, vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service rate for Profit Maximization')
s.invert_yaxis()

s = sns.heatmap(pooled, annot=True, fmt=".2f", cmap='viridis', ax=ax2, vmin=0, vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service rate for Pooled Rides')
s.invert_yaxis()


s = sns.heatmap(solo, annot=True, fmt=".2f", cmap='viridis', ax=ax3,  vmin=0, vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service rate for  Solo Rides')
s.invert_yaxis()

#veh_kpis[]
fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Set style and font size for the plot
sns.set(style="whitegrid")
sns.set_context("notebook", font_scale=1.2)

# Set figure size and autolayout
plt.rcParams["figure.figsize"] = [13.50, 4]
plt.rcParams["figure.autolayout"] = True

# Load data for different strategies
solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-3-ServiceRate/3 minutes/Solo-Rides.csv', index_col=0)
profitmax = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-3-ServiceRate/3 minutes/Profit-Maximization.csv', index_col=0)
pooled = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-3-ServiceRate/3 minutes/Pooled-Rides.csv', index_col=0)

# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=0.5)  # Adjust the horizontal spacing between subplots

# Heatmap for Profit Maximization
s = sns.heatmap(profitmax, annot=True, fmt=".2f", cmap='viridis', ax=ax1, vmin=0, vmax=100)
s.set(xlabel='Number of Travellers', ylabel='Number of Drivers', title='Service Rate for Profit Maximization')
s.invert_yaxis()

# Heatmap for Pooled Rides
s = sns.heatmap(pooled, annot=True, fmt=".2f", cmap='viridis', ax=ax2, vmin=0, vmax=100)
s.set(xlabel='Number of Travellers', ylabel='Number of Drivers', title='Service Rate for Pooled Rides')
s.invert_yaxis()

# Heatmap for Solo Rides
s = sns.heatmap(solo, annot=True, fmt=".2f", cmap='viridis', ax=ax3, vmin=0, vmax=100)
s.set(xlabel='Number of Travellers', ylabel='Number of Drivers', title='Service Rate for Solo Rides')
s.invert_yaxis()

# Adjust layout
fig.tight_layout()

# Show the plot
plt.show()
fig.savefig('ServiceRate3min.png', dpi=600)

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Aug 9 12:54:58 2023
@author: Usman Akhtar
"""
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('D:\Development\GitHub-ProjectV2.0\MaaSSim\docs\Experiments\data.csv')

data.fillna(0, inplace=True)

time_values = data['Time']
service_rate1_values = data['service rate1']
service_rate2_values = data['service rate2']
service_rate3_values = data['service rate3']

# Combine data for Seaborn
seaborn_data = pd.melt(data, id_vars='Time', value_vars=['service rate1', 'service rate2', 'service rate3'],
                       value_name='Service Rate %', var_name='Service')

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# Define a custom palette with colors for the bars
custom_palette = ['b', 'g', 'r']
sns.set_palette(custom_palette)

# Create a bar plot using Seaborn with hatching patterns
ax = sns.barplot(data=seaborn_data, x='Time', y='Service Rate %', hue='Service', alpha=0.8)

# Apply hatching patterns to each bar
hatches = ['//', '\\\\', 'x']
for i, patch in enumerate(ax.patches):
    hatch = hatches[i % len(hatches)]
    patch.set_hatch(hatch)

# Adjust other formatting
ax.set_xlabel('Time', fontsize=12)
ax.set_ylabel('Service Rate %', fontsize=12)
ax.set_title('Service Rates of Different KPIs', fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend(title='Service', title_fontsize=10, fontsize=10)

plt.xticks(rotation=0)
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'service rate1'
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('D:\Development\GitHub-ProjectV2.0\MaaSSim\docs\Experiments\data.csv')

data.fillna(0, inplace=True)

time_values = data['Time']
service_rate1_values = data['service rate1']
service_rate2_values = data['service rate2']
service_rate3_values = data['service rate3']

# Combine data for Seaborn
seaborn_data = pd.melt(data, id_vars='Time', value_vars=['service rate1', 'service rate2', 'service rate3'],
                       value_name='Service Rate %', var_name='Service')

sns.set(style="whitegrid", font_scale=1.2)  # Set font scale for better readability
plt.figure(figsize=(10, 6))

# Define a custom palette with distinct and contrasting colors for the bars
custom_palette = ['#3498db', '#27ae60', '#e74c3c']
sns.set_palette(custom_palette)

# Create a bar plot using Seaborn with hatching patterns
ax = sns.barplot(data=seaborn_data, x='Time', y='Service Rate %', hue='Service', alpha=0.8)

# Apply hatching patterns to each bar
hatches = ['//', '\\\\', 'x']
for i, patch in enumerate(ax.patches):
    hatch = hatches[i % len(hatches)]
    patch.set_hatch(hatch)

# Adjust other formatting
ax.set_xlabel('Waiting Time', fontsize=14)
ax.set_ylabel('Service Rate %', fontsize=14)
ax.set_title('Service Rates of Pricing Strategies', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.legend(title='Service', title_fontsize=12, fontsize=12)

plt.xticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('D:\Development\GitHub-ProjectV2.0\MaaSSim\docs\Experiments\data.csv')

data.fillna(0, inplace=True)

time_values = data['Time']
service_rate1_values = data['service rate1']
service_rate2_values = data['service rate2']
service_rate3_values = data['service rate3']

# Combine data for Seaborn
seaborn_data = pd.melt(data, id_vars='Time', value_vars=['service rate1', 'service rate2', 'service rate3'],
                       value_name='Service Rate %', var_name='Service')

sns.set(style="whitegrid", font_scale=1.2)  # Set font scale for better readability
plt.figure(figsize=(8, 6))  # Smaller figure size

# Define a custom palette with distinct and contrasting colors for the bars
custom_palette = ['#3498db', '#27ae60', '#e74c3c']
sns.set_palette(custom_palette)

# Create a bar plot using Seaborn with hatching patterns
ax = sns.barplot(data=seaborn_data, x='Time', y='Service Rate %', hue='Service', alpha=0.8)

# Apply hatching patterns to each bar
hatches = ['//', '\\\\', 'x']
for i, patch in enumerate(ax.patches):
    hatch = hatches[i % len(hatches)]
    patch.set_hatch(hatch)

# Adjust other formatting
ax.set_xlabel('Waiting Time', fontsize=14)
ax.set_ylabel('Service Rate %', fontsize=14)
ax.set_title('Service Rates of Pricing Policies', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.legend(title='Service', title_fontsize=12, fontsize=12)

plt.xticks(rotation=0)
plt.tight_layout()

# Save the first plot
plt.savefig('plot1.png', dpi=600)  # Save the plot to a file

# Create a new plot with the same settings
#plt.figure(figsize=(8, 6))  # Smaller figure size

# Create another bar plot or any other plot you want to display

# Save the second plot
#plt.savefig('plot2.png', dpi=300)  # Save the plot to a file

plt.show()  # Display the plots

# %% [markdown]
# # KPI-4: Operating Cost

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.style.use('seaborn-whitegrid')
font = {'size'   : 10}


plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-4-OperatingCost/Solo-Rides.csv', index_col=0)
#solo=solo.drop('0',axis='columns')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-4-OperatingCost/Profit-Maximization.csv', index_col=0)
#profitmax=profitmax.drop('0',axis='columns')

pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-4-OperatingCost/Pooled-Rides.csv', index_col=0)
#pooled=pooled.drop('0',axis='columns')
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)

#sns.heatmap(veh_kpis, cmap="Blues", ax = axes[1], square = True, cbar = True, cbar_ax = cbar_ax)

s = sns.heatmap(profitmax, annot=True,  fmt=".2f", cmap='Blues', ax=ax1, vmin=0,  vmax=28)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Operating Cost for Profit Maximization')
s.invert_yaxis()
s = sns.heatmap(pooled, annot=True, fmt=".2f", cmap='Blues', ax=ax2, vmin=0, vmax=28)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Operating Cost for Pooled Rides')
s.invert_yaxis()
s = sns.heatmap(solo, annot=True, fmt=".2f", cmap='Blues', ax=ax3,  vmin=0, vmax=28)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Operating Cost for  Solo Rides')
s.invert_yaxis()
txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

#veh_kpis[]
fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# # KPI-5: Driving Time

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.style.use('seaborn-whitegrid')
font = {'size'   : 10}


plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-5-DrivingTime/DT_Solo-Rides.csv', index_col=0)
#solo=solo.drop('0',axis='columns')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-5-DrivingTime/DT_Profit-Maximization.csv', index_col=0)
#profitmax=profitmax.drop('0',axis='columns')

pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-5-DrivingTime/DT_Pooled-Rides.csv', index_col=0)
#pooled=pooled.drop('0',axis='columns')


for col in solo.columns:
    solo[col]=solo[col]//3600*4
   # data.head()
    
for col in profitmax.columns:
    profitmax[col]=profitmax[col]//3600*4
    #data1.head()
    
     
for col in pooled.columns:
    pooled[col]=pooled[col]//3600*4
   # data2.head() 
    
    
    
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)

#sns.heatmap(veh_kpis, cmap="Blues", ax = axes[1], square = True, cbar = True, cbar_ax = cbar_ax)

s = sns.heatmap(profitmax, annot=True,  fmt=".2f", cmap='Blues', ax=ax1, vmin=0, vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Driving Time for Profit Maximization')
s.invert_yaxis()
s = sns.heatmap(pooled, annot=True, fmt=".2f", cmap='Blues', ax=ax2, vmin=0,  vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Driving Time  for Pooled Rides')
s.invert_yaxis()
s = sns.heatmap(solo, annot=True, fmt=".2f", cmap='Blues', ax=ax3,  vmin=0,  vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Driving Time  for  Solo Rides')
s.invert_yaxis()
txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

#veh_kpis[]
fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# # KPI-6: Driving Distance

# %% [markdown]
# # KPI-7: Pickup Distance

# %% [markdown]
# # KPI-8: Travel Distance

# %% [markdown]
# # KPI-9: Travel Time

# %% [markdown]
# # KPI-10: Waiting Time
