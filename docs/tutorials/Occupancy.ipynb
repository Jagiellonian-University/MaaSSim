# %% [markdown]
# ## Simulation of Occupany

# %% [markdown]
# ## Rep 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Increase the font size
plt.rcParams.update({'font.size': 12})

# Increase the figure size
plt.rcParams["figure.figsize"] = [16, 6] 


#solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/Pooled/rep1/Occupancy.csv',index_col=0)
#solo=solo.drop('0',axis='columns')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/ProfitMax/rep1/Occupancy.csv',index_col=0)
#profitmax=profitmax.drop('0',axis='columns')

pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/Pooled/rep1/Occupancy.csv', index_col=0)
#pooled=pooled.drop('0',axis='columns')


fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.5)  # Adjust the space here (e.g., increase/decrease the value)

#sns.heatmap(veh_kpis, cmap="Blues", ax = axes[1], square = True, cbar = True, cbar_ax = cbar_ax)

s = sns.heatmap(profitmax, annot=True,  fmt=".3f", cmap='viridis', ax=ax1, vmin=1, vmax=1.55)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Occupancy for Profit Maximization')
#s.invert_yaxis()

s = sns.heatmap(pooled, annot=True, fmt=".3f", cmap='viridis', ax=ax2, vmin=1, vmax=1.55)
s.set(xlabel='number of Travellers', ylabel='', title = 'Occupancy for Pooled Rides')
#s.invert_yaxis()



#veh_kpis[]
fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# ## Rep 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Increase the font size
plt.rcParams.update({'font.size': 12})

# Increase the figure size
# Increase the figure size
plt.rcParams["figure.figsize"] = [16, 6]  # Adjust the figure size


#solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/Pooled/rep1/Occupancy.csv',index_col=0)
#solo=solo.drop('0',axis='columns')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/ProfitMax/rep2/Occupancy.csv',index_col=0)
#profitmax=profitmax.drop('0',axis='columns')

pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/Pooled/rep2/Occupancy.csv', index_col=0)
#pooled=pooled.drop('0',axis='columns')
fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=1.01)

#sns.heatmap(veh_kpis, cmap="Blues", ax = axes[1], square = True, cbar = True, cbar_ax = cbar_ax)

s = sns.heatmap(profitmax, annot=True,  fmt=".3f", cmap='viridis', ax=ax1, vmin=1, vmax=1.55)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Occupancy for Profit Maximization')
s.invert_yaxis()

s = sns.heatmap(pooled, annot=True, fmt=".3f", cmap='viridis', ax=ax2, vmin=1, vmax=1.55)
s.set(xlabel='number of Travellers', ylabel='', title = 'Occupancy for Pooled Rides')
s.invert_yaxis()



#veh_kpis[]
fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# ## Rep 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Increase the font size
plt.rcParams.update({'font.size': 12})

# Increase the figure size
plt.rcParams["figure.figsize"] = [16, 6] 


#solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/Pooled/rep1/Occupancy.csv',index_col=0)
#solo=solo.drop('0',axis='columns')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/ProfitMax/rep3/Occupancy.csv',index_col=0)
#profitmax=profitmax.drop('0',axis='columns')

pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/Pooled/rep3/Occupancy.csv', index_col=0)
#pooled=pooled.drop('0',axis='columns')
fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=1.01)

#sns.heatmap(veh_kpis, cmap="Blues", ax = axes[1], square = True, cbar = True, cbar_ax = cbar_ax)

s = sns.heatmap(profitmax, annot=True,  fmt=".3f", cmap='viridis', ax=ax1, vmin=1, vmax=1.55)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Occupancy for Profit Maximization')
s.invert_yaxis()

s = sns.heatmap(pooled, annot=True, fmt=".3f", cmap='viridis', ax=ax2, vmin=1, vmax=1.55)
s.set(xlabel='number of Travellers', ylabel='', title = 'Occupancy for Pooled Rides')
s.invert_yaxis()



#veh_kpis[]
fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# ## Rep 4

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Increase the font size
plt.rcParams.update({'font.size': 12})

# Increase the figure size
plt.rcParams["figure.figsize"] = [16, 6] 

#solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/Pooled/rep1/Occupancy.csv',index_col=0)
#solo=solo.drop('0',axis='columns')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/ProfitMax/rep4/Occupancy.csv',index_col=0)
#profitmax=profitmax.drop('0',axis='columns')

pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/Pooled/rep4/Occupancy.csv', index_col=0)
#pooled=pooled.drop('0',axis='columns')
fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=1.01)

#sns.heatmap(veh_kpis, cmap="Blues", ax = axes[1], square = True, cbar = True, cbar_ax = cbar_ax)

s = sns.heatmap(profitmax, annot=True,  fmt=".3f", cmap='viridis', ax=ax1, vmin=1, vmax=1.55)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Occupancy for Profit Maximization')
s.invert_yaxis()

s = sns.heatmap(pooled, annot=True, fmt=".3f", cmap='viridis', ax=ax2, vmin=1, vmax=1.55)
s.set(xlabel='number of Travellers', ylabel='', title = 'Occupancy for Pooled Rides')
s.invert_yaxis()



#veh_kpis[]
fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# New travel time data
travel_time_data = np.array([
   [28260.25,56242.75,44403.5,36490.5,21564],
[25774.75,55780.75,88049.75,116364,128795.5],
[27574,56784.5,87613.75,115764.75,144318.75],
[27981.5,55804,85290.75,119350,147090],
[27976.5,57196.25,86212.5,111587.25,116905.75]
])

# New driving time data
driving_time_data = np.array([
   [22843.75,41503.25,28645.5,23459.25,18746.5],
[21695.25,40380,57591.25,73208.25,84086.5],
[22465.25,42137,59176,74177.75,90707.75],
[22757.5,41267,58143.25,76427.25,89381.25],
[22516,42082.25,58107.25,73220.75,89332]
])

# Calculate occupancy by dividing travel time by driving time
df_data = travel_time_data / driving_time_data

#pd.DataFrame(df_data).to_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-8-Occupancy/Rep/Occupancy/Pooled/rep4/Occupancy.csv')

# Define number of drivers and travelers
drivers = np.arange(10, 51, 10)
travelers = np.arange(100, 501, 100)

# Create a DataFrame for occupancy
print(df_data)

# Set up the figure for the heatmap
plt.figure(figsize=(10, 8))

# Create the heatmap using Seaborn with a different colormap and annotations
heatmap = sns.heatmap(df_data, annot=True, fmt='.3f',  cmap='viridis', vmin=1, vmax=1.6, linewidths=0.5, cbar_kws={'label': 'Occupancy'})

# Reverse the y-axis
plt.gca().invert_yaxis()

# Set y-axis labels
plt.xlabel('Number of Drivers')
plt.ylabel('Number of Travelers')
plt.title('Occupancy with Pooled Ride')

# Show the plot
plt.show()
# Out:
# [[1.23711081 1.35514086 1.55010386 1.55548451 1.15029472]
#  [1.18803655 1.38139549 1.52887374 1.58949299 1.53170247]
#  [1.22740677 1.34761611 1.48056222 1.56063981 1.59102998]
#  [1.2295507  1.35226694 1.46690716 1.56161578 1.64564716]
#  [1.24251643 1.3591538  1.48367889 1.52398398 1.30866599]]
