# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/ServiceRate/Solo-Rides.csv')
profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/ServiceRate/Profit-Maximization.csv')
pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/ServiceRate/Pooled-Rides.csv')

# %%
ax = sns.heatmap(solo,annot=True,cmap='viridis')

# %%
s = sns.heatmap(solo, annot=True,  cmap='viridis')
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Solo Rides')
# Out:
# [Text(0.5, 15.0, 'number of Travellers'),
#  Text(33.0, 0.5, 'number of Drivers'),
#  Text(0.5, 1.0, 'Service Rate for Solo Rides')]

# %%
s = sns.heatmap(profitmax, annot=True,  cmap='viridis')
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Profit Maximization')
# Out:
# [Text(0.5, 15.0, 'number of Travellers'),
#  Text(33.0, 0.5, 'number of Drivers'),
#  Text(0.5, 1.0, 'Service Rate for Profit Maximization')]

# %%
s = sns.heatmap(pooled, annot=True,  cmap='viridis')
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Pooled Rides')
# Out:
# [Text(0.5, 15.0, 'number of Travellers'),
#  Text(33.0, 0.5, 'number of Drivers'),
#  Text(0.5, 1.0, 'Service Rate for Pooled Rides')]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(ncols=3)

s = sns.heatmap(profitmax, annot=True,  cmap='viridis')
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Profit Maximization')

s = sns.heatmap(pooled, annot=True,  cmap='viridis')
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Pooled Rides')

s = sns.heatmap(solo, annot=True,  cmap='viridis')
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Solo Rides')
# Out:
# [Text(0.5, 6.125, 'number of Travellers'),
#  Text(269.3294117647059, 0.5, 'number of Drivers'),
#  Text(0.5, 1.0, 'Service Rate for Solo Rides')]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True


solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/ServiceRate/Solo-Rides.csv')
profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/ServiceRate/Profit-Maximization.csv')
pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/ServiceRate/Pooled-Rides.csv')

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  cmap='viridis', ax=ax1)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Profit Maximization')

s = sns.heatmap(pooled, annot=True,  cmap='viridis', ax=ax2)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Pooled Rides')

s = sns.heatmap(solo, annot=True,  cmap='viridis', ax=ax3)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
fig.savefig('ServiceRate.png', dpi=600)

# %%
fig = plt.figure(figsize=(10,5))
f, a = plt.subplots(2, 2, figsize=(8,5 ))
#  subplot #1
plt.subplot(221)
plt.title('Pooled Rides')
sns.heatmap(data = pooled,annot=True,fmt=".1f")

plt.ylabel('Rides',fontsize=13)

#  subplot #2
plt.subplot(222)
plt.title('Solo Rides')
sns.heatmap(data = solo,annot=True,fmt=".1f")
# plt.xlabel('',fontsize=13)
# plt.ylabel('Rides',fontsize=13)

#  subplot #3
plt.subplot(223)
plt.title('Profit Maximization')
sns.heatmap(data = profitmax,annot=True,fmt=".1f",linewidths=4,xticklabels=data1)
plt.xlabel('Drivers',fontsize=13)
plt.ylabel('Rides',fontsize=13)

#  subplot #4
plt.subplot(224)
plt.title('Solo Rides')
sns.heatmap(data = solo,annot=True,fmt=".1f",xticklabels=data2)
plt.xlabel('Drivers',fontsize=13)
plt.suptitle('Pooled vs Solo vs Profit',fontsize=23)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 20>()
#      18 plt.subplot(223)
#      19 plt.title('Profit Maximization')
# ---> 20 sns.heatmap(data = profitmax,annot=True,fmt=".1f",linewidths=4,xticklabels=data1)
#      21 plt.xlabel('Drivers',fontsize=13)
#      22 plt.ylabel('Rides',fontsize=13)
#
# NameError: name 'data1' is not defined
