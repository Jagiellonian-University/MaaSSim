# %% [markdown]
# # KPI-I: Service rate

# %%
import pandas as pd

PR = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Pooled-Rides.csv')
print(PR)
SR = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Solo-Rides.csv')
print(SR)
# Out:
#     0   100   200    300    400   500
# 0   5  28.9  18.5  10.60   8.20   8.2
# 1  10  92.0  44.5  15.66  15.23  14.2
# 2  20  91.0  90.5  61.23  40.20  27.4
# 3  30  99.8  99.5  97.60  75.50  56.6
# 4  40  99.0  99.5  98.60  98.00  82.2
# 5  50  98.0  99.0  99.10  98.00  98.0
#     0  100   200    300    400   500
# 0   5   34  16.5  16.00   7.50   6.6
# 1  10   88  47.0  17.00  19.25  14.0
# 2  20   98  87.5  58.66  35.75  28.9
# 3  30   98  99.5  99.00  69.00  59.3
# 4  40   99  98.5  99.30  96.75  83.0
# 5  50   99  97.5  98.00  98.75  89.2

# %%
df = PR.div(SR, level=1, fill_value=1)
print (df)
# Out:
#      0       100       200       300       400       500
# 0  1.0  0.850000  1.121212  0.662500  1.093333  1.242424
# 1  1.0  1.045455  0.946809  0.921176  0.791169  1.014286
# 2  1.0  0.928571  1.034286  1.043812  1.124476  0.948097
# 3  1.0  1.018367  1.000000  0.985859  1.094203  0.954469
# 4  1.0  1.000000  1.010152  0.992951  1.012920  0.990361
# 5  1.0  0.989899  1.015385  1.011224  0.992405  1.098655

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.title('Pooled-Rides/SoloRides Ratio')
sns.heatmap(data = df,annot=True,fmt=".2f",cmap='viridis')
plt.xlabel('number of Travellers',fontsize=10)
plt.ylabel('number of Drivers',fontsize=10)
# Out:
# Text(6.800000000000004, 0.5, 'number of Drivers')

# %%
PMR = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Profit-Maximization.csv')
print(PMR)
SR = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Solo-Rides.csv')
print(SR)
df1 = PMR.div(SR, level=1, fill_value=1)
print (df1)
# Out:
#     0   100   200    300    400   500
# 0   5  43.0  21.0  18.33   8.25  10.8
# 1  10  82.0  36.0  25.30  16.25  21.0
# 2  20  97.5  90.5  60.23  42.25  38.0
# 3  30  99.0  98.7  98.33  85.50  68.0
# 4  40  98.0  98.5  99.00  98.50  89.0
# 5  50  99.0  99.0  99.60  98.00  99.0
#     0  100   200    300    400   500
# 0   5   34  16.5  16.00   7.50   6.6
# 1  10   88  47.0  17.00  19.25  14.0
# 2  20   98  87.5  58.66  35.75  28.9
# 3  30   98  99.5  99.00  69.00  59.3
# 4  40   99  98.5  99.30  96.75  83.0
# 5  50   99  97.5  98.00  98.75  89.2
#      0       100       200       300       400       500
# 0  1.0  1.264706  1.272727  1.145625  1.100000  1.636364
# 1  1.0  0.931818  0.765957  1.488235  0.844156  1.500000
# 2  1.0  0.994898  1.034286  1.026764  1.181818  1.314879
# 3  1.0  1.010204  0.991960  0.993232  1.239130  1.146712
# 4  1.0  0.989899  1.000000  0.996979  1.018088  1.072289
# 5  1.0  1.000000  1.015385  1.016327  0.992405  1.109865

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.title('Profit Maximization/SoloRides Ratio')
sns.heatmap(data = df1,annot=True,fmt=".2f",cmap='viridis')
plt.xlabel('number of Travellers',fontsize=10)
plt.ylabel('number of Drivers',fontsize=10)
# Out:
# Text(6.800000000000004, 0.5, 'number of Drivers')

# %%
compdf=df.compare(df1,align_axis=0,keep_shape=True,keep_equal=True).rename(index={'self':'PR/Solo','other':'PMR/solo'},level=-1)

# %%
compdf.head()
# Out:
#               0       100       200       300       400       500
# 0 PR/Solo   1.0  0.850000  1.121212  0.662500  1.093333  1.242424
#   PMR/solo  1.0  1.264706  1.272727  1.145625  1.100000  1.636364
# 1 PR/Solo   1.0  1.045455  0.946809  0.921176  0.791169  1.014286
#   PMR/solo  1.0  0.931818  0.765957  1.488235  0.844156  1.500000
# 2 PR/Solo   1.0  0.928571  1.034286  1.043812  1.124476  0.948097

# %%
plt.rcParams["figure.figsize"] = [7, 4.50]
plt.rcParams["figure.autolayout"] = True
plt.title('comparing both ratios')
sns.heatmap(data = compdf,annot=True,fmt=".2f",cmap='viridis')
plt.xlabel('number of Travellers',fontsize=10)
plt.ylabel('number of Drivers',fontsize=10)
# Out:
# Text(6.800000000000004, 0.5, 'number of Drivers')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True


solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Solo-Rides.csv')
profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Profit-Maximization.csv')
pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Pooled-Rides.csv')

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".2f", cmap='viridis', ax=ax1, vmin=0,vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Profit Maximization')

s = sns.heatmap(pooled, annot=True, fmt=".2f", cmap='viridis', ax=ax2, vmin=0,vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Pooled Rides')

s = sns.heatmap(solo, annot=True, fmt=".2f", cmap='viridis', ax=ax3, vmin=0,vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# ## Comparion of Service rate

# %%
import pandas as pd

data2 = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Solo-Rides.csv')
data1 =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Profit-Maximization.csv')
data =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Pooled-Rides.csv')


colListPR=[]
for column in data.columns:
     
    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()
     
    # appending the temporary list
    colListPR.append(li)
     
# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:
     
    li =data1[column].tolist()
     
    colListPM.append(li)
     
#print(colListPM)

colListSR=[]
for column in data2.columns:
     
    li =data2[column].tolist()
     
    colListSR.append(li)
     
#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

from plotly.offline import plot, iplot, init_notebook_mode
import plotly.graph_objs as go
init_notebook_mode(connected=True)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='KPI 1 Analysis',xaxis=dict(title='Drivers'),yaxis=dict(title='Rides'))
fig.show()
#plt.savefig("KPI1Analysis.jpg")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Service Rate')
sns.distplot(flatPR,hist=False,label='Pooled')
sns.distplot(flatPM,hist=False,label='Profit Maximization')
sns.distplot(flatSR,hist=False,label='Solo')
plt.xlabel('Drivers',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()

# %% [markdown]
# # KPI-2: Idle Time

# %% [markdown]
# ## Comparison of Idle Time

# %%
import pandas as pd

data2 = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-3-IdleTime/IdleTime_Solo-Rides.csv')

data1 =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-3-IdleTime/IdleTime_Profit-Maximization.csv')
data =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-3-IdleTime/IdleTime_Pooled-Rides.csv')

for col in data.columns:
    data[col]=data[col]//3600
    data.head()
    
for col in data1.columns:
    data1[col]=data1[col]//3600
    data1.head()
    
     
for col in data1.columns:
    data2[col]=data2[col]//3600
    data2.head()   
    
colListPR=[]
for column in data.columns:
     
    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()
     
    # appending the temporary list
    colListPR.append(li)
     
# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:
     
    li =data1[column].tolist()
     
    colListPM.append(li)
     
#print(colListPM)

colListSR=[]
for column in data2.columns:
     
    li =data2[column].tolist()
     
    colListSR.append(li)
     
#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Analysis of Idle Time',xaxis=dict(title='Drivers'),yaxis=dict(title='Rides'))
fig.show()
#plt.savefig("KPI1Analysis.jpg")


#############################################
import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Idle Time')
sns.distplot(flatPR,hist=False,label='Pooled')
sns.distplot(flatPM,hist=False,label='Profit Maximization')
sns.distplot(flatSR,hist=False,label='Solo')
plt.xlabel('Drivers',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()

# %% [markdown]
# # KPI-3: Revenue

# %%
import pandas as pd

data2 = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-1-Revenue/Revenue_Solo-Rides.csv')

data1 =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-1-Revenue/Revenue_Profit-Maximization.csv')
data =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-1-Revenue/Revenue_Pooled-Rides.csv')


colListPR=[]
for column in data.columns:
     
    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()
     
    # appending the temporary list
    colListPR.append(li)
     
# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:
     
    li =data1[column].tolist()
     
    colListPM.append(li)
     
print(colListPM)

colListSR=[]
for column in data2.columns:
     
    li =data2[column].tolist()
     
    colListSR.append(li)
     
#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Analysis of Revenue',xaxis=dict(title='Comparsion of Strategies'),yaxis=dict(title='Revenue'))
fig.show()
#plt.savefig("KPI1Analysis.jpg")


#############################################

import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Revenue')
sns.distplot(flatPR,hist=False,label='Pooled')
sns.distplot(flatPM,hist=False,label='Profit Maximization')
sns.distplot(flatSR,hist=False,label='Solo')
plt.xlabel('Drivers',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()
# Out:
# [[260.474, 270.851, 278.426, 256.914], [528.278, 513.209, 524.692, 525.275], [802.675, 772.192, 780.662, 855.0], [1125.707, 1069.642, 1021.134, 1034.751], [1312.125, 1328.86, 1309.853, 1292.01]]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-1-Revenue/Revenue_Solo-Rides.csv')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-1-Revenue/Revenue_Profit-Maximization.csv')
pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-1-Revenue/Revenue_Pooled-Rides.csv')



fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".1f", cmap='viridis', ax=ax1)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Revenue of Profit Maximization')

s = sns.heatmap(pooled, annot=True, fmt=".1f", cmap='viridis', ax=ax2)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Revenue of   Pooled Rides')

s = sns.heatmap(solo, annot=True, fmt=".1f", cmap='viridis', ax=ax3)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Revenue of Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# # KPI-4: Arrival Time (time to arrive for traveller)

# %%
import pandas as pd

data2 = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-4-ArrivalTime/ArrivalTime_Solo-Rides.csv')
data1 =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-4-ArrivalTime/ArrivalTime_Profit-Maximization.csv')
data =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-4-ArrivalTime/ArrivalTime_Pooled-Rides.csv')

for col in data.columns:
    data[col]=data[col]//60
    data.head()
    
for col in data1.columns:
    data1[col]=data1[col]//60
    data1.head()
    
     
for col in data1.columns:
    data2[col]=data2[col]//60
    data2.head() 
    

colListPR=[]
for column in data.columns:
     
    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()
     
    # appending the temporary list
    colListPR.append(li)
     
# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:
     
    li =data1[column].tolist()
     
    colListPM.append(li)
     
print(colListPM)

colListSR=[]
for column in data2.columns:
     
    li =data2[column].tolist()
     
    colListSR.append(li)
     
#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Arrival Time',xaxis=dict(title='Comparsion of Strategies'),yaxis=dict(title='Arrival Time'))
fig.show()
#plt.savefig("KPI1Analysis.jpg")


#############################################
# Out:
# [[0, 0, 0, 0, 0], [242, 3621, 4811, 8276, 10850], [308, 1657, 2770, 5518, 8680], [1254, 709, 2553, 4236, 10406], [1288, 411, 1911, 3534, 6051], [1442, 871, 1062, 2148, 5062]]

# %% [markdown]
# # KPI-5: Travel Time (Paid Time)

# %%
import pandas as pd

data2 = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-5-TravelTime/Travel_Solo-Rides.csv')
data1 =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-5-TravelTime/Travel_Profit-Maximization.csv')
data =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-5-TravelTime/Travel_Pooled-Rides.csv')

for col in data.columns:
    data[col]=data[col]//3600
    data.head()
    
for col in data1.columns:
    data1[col]=data1[col]//3600
    data1.head()
    
     
for col in data1.columns:
    data2[col]=data2[col]//3600
    data2.head() 

colListPR=[]
for column in data.columns:
     
    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()
     
    # appending the temporary list
    colListPR.append(li)
     
# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:
     
    li =data1[column].tolist()
     
    colListPM.append(li)
     
print(colListPM)

colListSR=[]
for column in data2.columns:
     
    li =data2[column].tolist()
     
    colListSR.append(li)
     
#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Travel Time',xaxis=dict(title='Comparsion of Strategies'),yaxis=dict(title='Revenue'))
fig.show()
#plt.savefig("KPI1Analysis.jpg")


#############################################

import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Travel Time')
sns.distplot(flatPR,hist=False,label='Pooled')
sns.distplot(flatPM,hist=False,label='Profit Maximization')
sns.distplot(flatSR,hist=False,label='Solo')
plt.xlabel('Drivers',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '16874'
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True



solo = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-5-TravelTime/Travel_Solo-Rides.csv')

profitmax =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-5-TravelTime/Travel_Profit-Maximization.csv')
pooled =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-5-TravelTime/Travel_Pooled-Rides.csv')



fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".1f", cmap='viridis', ax=ax1)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Revenue of Profit Maximization')

s = sns.heatmap(pooled, annot=True, fmt=".1f", cmap='viridis', ax=ax2)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Revenue of   Pooled Rides')

s = sns.heatmap(solo, annot=True, fmt=".1f", cmap='viridis', ax=ax3)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Revenue of Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# ## Waiting Time (Time Waiting for Travellers)

# %%
import pandas as pd

data2 = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-6-WaitingTime/Waiting_Solo-Rides.csv')
data1 =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-6-WaitingTime/Waiting_Profit-Maximization.csv')
data =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-6-WaitingTime/Waiting_Pooled-Rides.csv')


colListPR=[]
for column in data.columns:
     
    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()
     
    # appending the temporary list
    colListPR.append(li)
     
# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:
     
    li =data1[column].tolist()
     
    colListPM.append(li)
     
print(colListPM)

colListSR=[]
for column in data2.columns:
     
    li =data2[column].tolist()
     
    colListSR.append(li)
     
#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Waiting Time',xaxis=dict(title='Comparsion of Strategies'),yaxis=dict(title='Waiting Time'))
fig.show()
#plt.savefig("KPI1Analysis.jpg")


#############################################

import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Waiting Time')
sns.distplot(flatPR,hist=False,label='Pooled')
sns.distplot(flatPM,hist=False,label='Profit Maximization')
sns.distplot(flatSR,hist=False,label='Solo')
plt.xlabel('Waiting Time',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()
# Out:
# [[10, 20, 30, 40, 50], [74068, 163643, 147697, 87916, 138025], [391469, 358189, 333978, 320005, 311750], [694907, 632598, 606754, 732418, 615135], [865513, 849849, 894249, 879267, 905836], [97306, 1239673, 1166228, 1172783, 1130796]]

# %% [markdown]
# ## Random

# %%
import pandas as pd

data = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Pooled-Rides.csv')

data1 = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Profit-Maximization.csv')
data2 = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Solo-Rides.csv')

# %%
data
# Out:
#     0   100   200    300    400   500
# 0   5  28.9  18.5  10.60   8.20   8.2
# 1  10  92.0  44.5  15.66  15.23  14.2
# 2  20  91.0  90.5  61.23  40.20  27.4
# 3  30  99.8  99.5  97.60  75.50  56.6
# 4  40  99.0  99.5  98.60  98.00  82.2
# 5  50  98.0  99.0  99.10  98.00  98.0

# %%
import warnings
warnings.simplefilter('ignore')
fig= plt.figure(figsize=(15,10),dpi=150)
fig,ax =plt.subplots()
plt.title('Service Rate')
sns.distplot(data,hist=False,label='Pooled')
#plt.xlim(100,500)

sns.distplot(data1,hist=False,label='Profit Maximization')
#plt.xlim(100,500)

sns.distplot(data2,hist=False,label='Solo')
plt.xlabel('Drivers',fontsize=13)
plt.ylabel('Rides',fontsize=13)
#plt.xlim(100,500)

plt.legend(fontsize=10)
plt.savefig("Revinue.jpg")
plt.show()

# %%
import matplotlib.axes as ax
import matplotlib.pyplot as plt

ProfitMax = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/ProfitMax.csv')
PooledRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PooledRide.csv')
PrivateRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PrivateRide.csv')



sns.kdeplot(ProfitMax['REVENUE'], shade=True)
ax = sns.rugplot(data=ProfitMax['REVENUE'], color='C0', height=0.05)
#plt.axvline(data=ProfitMax['REVENUE'].mean(), linewidth=2, color='C0', label="mean",)

#ax[1].axvline(x=rwda["Driver idle time [sec]"].mean(), linewidth=2, color='C0', label="mean", alpha=0.5)


sns.kdeplot(PooledRide['REVENUE'], shade=True)
sns.rugplot(data=PooledRide['REVENUE'], color='C1', height=0.05)
#plt.axvline(data=PooledRide['REVENUE'].mean(), linewidth=2, color='C0', label="mean", alpha=0.5)



sns.kdeplot(PrivateRide['REVENUE'], shade=True)
sns.rugplot(data=PrivateRide['REVENUE'], color='C2', height=0.05)



plt.title('Revenue Distribution of Individual drivers'); 
plt.xlabel('Revenue'); plt.ylabel('Drivers');
