# %% [markdown]
# # Histograms and Density Plots

# %%
# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['figure.dpi'] = 300

import seaborn as sns

from IPython.core.pylabtools import figsize

# %% [markdown]
# # Data Import

# %%
 # Read in data
ProfitMax = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/ProfitMax.csv')
PooledRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PooledRide.csv')
PrivateRide = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PrivateRide.csv')

#ProfitMax.head(10)
#PooledRide.head(10)
PrivateRide.head(10)
# Out:
#    veh  nRIDES  nREJECTED    OUT  STARTS_DAY  OPENS_APP  RECEIVES_REQUEST  \
# 0    1       6        0.0  False           0          0              20.0
# 1    2       4        0.0  False           0          0             168.0
# 2    3       8        0.0  False           0          0              80.0
# 3    4      13        0.0  False           0          0              73.0
# 4    5       8        0.0  False           0          0             179.0
# 5    6       8        0.0  False           0          0              60.0
# 6    7      14        0.0  False           0          0             163.0
# 7    8       4        0.0  False           0          0              49.0
# 8    9       8        0.0  False           0          0              63.0
# 9   10      10        0.0  False           0          0              74.0
#
#    ACCEPTS_REQUEST  REJECTS_REQUEST  IS_ACCEPTED_BY_TRAVELLER  ...  \
# 0             15.0                0                     316.0  ...
# ...

# %% [markdown]
# # Profit Maximization

# %%
figsize(3, 2)

# Make the histogram using matplotlib, bins must be integet
sns.distplot(ProfitMax['REVENUE'], hist=True, kde=True, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title('Revenue Distribution of Individual drivers')
plt.xlabel('Revenue'); plt.ylabel('Drivers');

#ax = sns.displot(df.REVENUE, kde=True, binwidth=1)
# Out:
# C:\Users\usman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Pooled Ride

# %%
figsize(3, 2)

# Make the histogram using matplotlib, bins must be integet
sns.distplot(PooledRide['REVENUE'], hist=True, kde=True, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title('Revenue Distribution of Individual drivers')
plt.xlabel('Revenue'); plt.ylabel('Drivers');

#ax = sns.displot(df.REVENUE, kde=True, binwidth=1)
# Out:
# C:\Users\usman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Private Ride

# %%
figsize(3, 2)

# Make the histogram using matplotlib, bins must be integet
sns.distplot(PrivateRide['REVENUE'], hist=True, kde=True, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title('Revenue Distribution of Individual drivers')
plt.xlabel('Revenue'); plt.ylabel('Drivers');

#ax = sns.displot(df.REVENUE, kde=True, binwidth=1)
# Out:
# C:\Users\usman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Density Plot of revenue distribution (individual)

# %%
figsize(3, 2)

sns.distplot(ProfitMax['REVENUE'], hist=True, kde=True, 
             bins=int(100/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 1});

plt.title('Profit Max. Revenue Distribution of Individual drivers'); 
plt.xlabel('Revenue'); plt.ylabel('Drivers');
# Out:
# C:\Users\usman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
figsize(3, 2)

sns.distplot(PooledRide['REVENUE'], hist=True, kde=True, 
             bins=int(100/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 1});

plt.title('PooledRide. Revenue Distribution of Individual drivers'); 
plt.xlabel('Revenue'); plt.ylabel('Drivers');
# Out:
# C:\Users\usman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
figsize(3, 2)

sns.distplot(PrivateRide['REVENUE'], hist=True, kde=True, 
             bins=int(100/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 1});

plt.title('PrivateRide. Revenue Distribution of Individual drivers'); 
plt.xlabel('Revenue'); plt.ylabel('Drivers');
# Out:
# C:\Users\usman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Shaded Density

# %%
figsize(3, 2)

sns.kdeplot(ProfitMax['REVENUE'], shade=True);

sns.kdeplot(PooledRide['REVENUE'], shade=True);

sns.kdeplot(PrivateRide['REVENUE'], shade=True);



plt.title('Revenue Distribution of Individual drivers'); 
plt.xlabel('Revenue'); plt.ylabel('Drivers');

# %%
# Make a separate list for each airline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

Data=pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Plotting/PooledRide.csv')
#Data.head(10)
                 
figsize(3, 2)



sns.kdeplot(x=Data.REVENUE,y=Data.veh, shade=True);



plt.title('Revenue Distribution of Individual drivers'); 
plt.xlabel('Revenue'); plt.ylabel('Drivers');

# %%
# Make a separate list for each airline
import matplotlib.pyplot as plt
x1 = list(ProfitMax['REVENUE'])
x2 = list(PooledRide['REVENUE'])
x3 = list(PrivateRide['REVENUE'])


# Assign colors for each airline and the names
colors = ['#E69F00', '#56B4E9', '#009E73']
names = ['Profit Maximization', 'Pooled Rides', 'Private Rides']


figsize(5, 3)

# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([x1, x2, x3], bins = int(100/10), 
         color = colors, label=names)

# Plot formatting
plt.legend()
plt.xlabel('Revenue')
plt.ylabel('Drivers')
plt.title('Revenue Distributions');
