# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data2 = pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Solo-Rides.csv')
data1 =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Profit-Maximization.csv')
data =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Pooled-Rides.csv')

# %%
data
# Out:
#     0   100   200    300    400   500
# 0   5  28.9  18.5  10.60   8.20   8.2
# 1  10  92.0  44.5  15.66  15.23  14.2
# 2  20  91.0  90.5  61.23  40.20  27.4
# 3  30  99.8  99.5  97.60  75.50  56.6
# 4  40  99.0  99.5  98.60  98.00  82.2
# 5  50  98.0  99.0  99.10  98.00  98.0

# %%
data1
# Out:
#     0   100   200    300    400   500
# 0   5  43.0  21.0  18.33   8.25  10.8
# 1  10  82.0  36.0  25.30  16.25  21.0
# 2  20  97.5  90.5  60.23  42.25  38.0
# 3  30  99.0  98.7  98.33  85.50  68.0
# 4  40  98.0  98.5  99.00  98.50  89.0
# 5  50  99.0  99.0  99.60  98.00  99.0

# %%
data2
# Out:
#     0  100   200    300    400   500
# 0   5   34  16.5  16.00   7.50   6.6
# 1  10   88  47.0  17.00  19.25  14.0
# 2  20   98  87.5  58.66  35.75  28.9
# 3  30   98  99.5  99.00  69.00  59.3
# 4  40   99  98.5  99.30  96.75  83.0
# 5  50   99  97.5  98.00  98.75  89.2

# %%
Pooled_Rides =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Pooled-Rides.csv')
Profit_maximization =pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Profit-Maximization.csv')
Solo_Rides= pd.read_csv('D:/Development/GitHub-ProjectV2.0/MaaSSim/docs/tutorials/Results/Simulation/Driver/KPI-2-ServiceRate/Solo-Rides.csv')
plt.title('Service Rate')
plt.xticks([10,20,30,40,50],[100,200,300,400,500],rotation=45)
sns.boxplot([Pooled_Rides,Profit_maximization,Solo_Rides],meanline=True,showmeans=True,)
plt.savefig('Service_rate.png')
plt.show()
# Out:
# C:\Users\usman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 6>()
#       4 plt.title('Service Rate')
#       5 plt.xticks([10,20,30,40,50],[100,200,300,400,500],rotation=45)
# ----> 6 sns.boxplot([Pooled_Rides,Profit_maximization,Solo_Rides],meanline=True,showmeans=True,)
#       7 plt.savefig('Service_rate.png')
#       8 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
# ...

# %%
plt.figure(figsize=(12,8),dpi=120)
plt.title('Service Rate')
sns.pointplot(data=data,color='red',label='Pooled Rides')
sns.pointplot(data=data1,color='Yellow',label='Profit Maximization')
sns.pointplot(data=data2,color='blue',label='Solo Rides')
plt.legend(fontsize=10)
